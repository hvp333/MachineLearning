# %% [markdown]
# <a href="https://colab.research.google.com/github/hvp333/MachineLearning/blob/master/Skimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.io import imread,imshow

# %%
from skimage import data

# %%
image = data.astronaut()

# %%
imshow(image)

# %%
image_gray = imread('/content/sample_data/ipimage.jpeg',as_gray = True)

# %%
imshow(image_gray)

# %%
print(image_gray.shape)
# Out:
# (958, 1300)

# %%
print(image_gray)
# Out:
# [[0.05037725 0.07782824 0.08483804 ... 0.25485725 0.23132784 0.21564157]
#  [0.05429882 0.0769949  0.08091647 ... 0.29943098 0.30727412 0.31511725]
#  [0.06214196 0.0769949  0.08091647 ... 0.37981176 0.33667451 0.31706667]
#  ...
#  [0.20510431 0.20510431 0.20510431 ... 0.20510431 0.20510431 0.20510431]
#  [0.20510431 0.20510431 0.20510431 ... 0.20510431 0.20510431 0.20510431]
#  [0.20510431 0.20510431 0.20510431 ... 0.20510431 0.20510431 0.20510431]]

# %%
image_color = imread('/content/sample_data/ipimage.jpeg',as_gray = False)

# %%
imshow(image_color)

# %%
imshow(image_gray)

# %%
#Changing Image Format

# %%
from skimage.color import rgb2gray

# %%
img = imread('/content/sample_data/ipimage.jpeg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c69373f099b8> in <module>()
# ----> 1 img = imread('/content/sample_data/ipimage.jpeg')
#
# NameError: name 'imread' is not defined

# %%
from skimage.io import imread

# %%
img = imread('/content/sample_data/ipimage.jpeg')

# %%
new_img = rgb2gray(img)

# %%
plt.subplot(121) , imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0012a45f5918> in <module>()
# ----> 1 plt.subplot(121) , imshow(img)
#
# NameError: name 'plt' is not defined

# %%
from matplotlib.pyplot import *

# %%
plt.subplot(121) , imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0012a45f5918> in <module>()
# ----> 1 plt.subplot(121) , imshow(img)
#
# NameError: name 'plt' is not defined

# %%
plt.subplot(121), imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cfb7c3ce35be> in <module>()
# ----> 1 plt.subplot(121), imshow(img)
#
# NameError: name 'plt' is not defined

# %%
imgshow(img), imgshow(new_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-789e06cecfc9> in <module>()
# ----> 1 imgshow(img), imgshow(new_img)
#
# NameError: name 'imgshow' is not defined

# %%
imshow(img), imshow(new_img)
# Out:
# (<matplotlib.image.AxesImage at 0x7f8e2959c860>,
#  <matplotlib.image.AxesImage at 0x7f8e2959cbe0>)

# %%
imshow(img)

# %%
imshow(new_img)

# %%
plt.subplot(121), imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-cfb7c3ce35be> in <module>()
# ----> 1 plt.subplot(121), imshow(img)
#
# NameError: name 'plt' is not defined

# %%
import *
# Out:
#   File "<ipython-input-20-730b1f7ad8c9>", line 1
#     import *
#            ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(121), imshow(img)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f8e25430908>,
#  <matplotlib.image.AxesImage at 0x7f8e2546c208>)

# %%
plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('Grayscale Format') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ae4684ee85fa> in <module>()
#       2 plt.title('RGB Format')
#       3
# ----> 4 plt.subplot(122), imshow(img_new)
#       5 plt.title('Grayscale Format')
#       6
#
# NameError: name 'img_new' is not defined

# %%
from skimage.color import rgb2gray
from skimage.color import rgb2hsv
import matplotlib.pyplot as plt

img = imread('/content/sample_data/ipimage.jpeg')
img_gray = rgb2gray(img)
img_hsv = rgb2hsv(img)

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_gray)
plt.title('Grayscale Format') 

plt.subplot(123), imshow(img_hsv)
plt.title('HSV Format') 

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-907202055da1> in <module>()
#      13 plt.title('Grayscale Format')
#      14
# ---> 15 plt.subplot(123), imshow(img_hsv)
#      16 plt.title('HSV Format')
#      17
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1082
#    1083     fig = gcf()
# -> 1084     a = fig.add_subplot(*args, **kwargs)
#    1085     bbox = a.bbox
#    1086     byebye = []
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1365                     self._axstack.remove(ax)
#    1366
# -> 1367             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1368         self._axstack.add(key, a)
#    1369         self.sca(a)
#
# ...

# %%
from skimage.color import rgb2hsv


img = imread('/content/sample_data/ipimage.jpeg')
img_new = rgb2hsv(img)
import matplotlib.pyplot as plt

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('HSV Format') 

plt.show()
